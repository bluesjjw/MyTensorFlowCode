# %%
cd ..
# Out:
# /home/jiawei/code/github/MyTensorFlowCode/autoencoder

# %%
lr = 0.002

# %%
run autoencoder-cifar.py adam 0.002
# Out:
# ...
# Train autoencoder on cifar10 dataset
# ...
# Optimizer: adam
# Learning rate: 0.002
# Momentum: 0.9
# Train set shape: (50000, 3072)
# Test set shape: (10000, 3072)
# Model restore from file: init_cifar.ckpt
# Epoch: 0001 cost= 40159.164200000
# Epoch: 0002 cost= 28515.442370000
# Epoch: 0003 cost= 24858.036450000
# Epoch: 0004 cost= 23312.792850000
# Epoch: 0005 cost= 20678.519300000
# Epoch: 0006 cost= 19760.680580000
# Epoch: 0007 cost= 18886.727450000
# Epoch: 0008 cost= 18711.914405000
# Epoch: 0009 cost= 17233.415250000
# Epoch: 0010 cost= 16964.946415000
# Epoch: 0011 cost= 16778.657870000
# Epoch: 0012 cost= 16353.520240000
# Epoch: 0013 cost= 15560.995075000
# Epoch: 0014 cost= 15149.120530000
# Epoch: 0015 cost= 14592.710135000
# Epoch: 0016 cost= 13939.502480000
# Epoch: 0017 cost= 13270.748870000
# Epoch: 0018 cost= 13126.948045000
# Epoch: 0019 cost= 13487.634075000
# Epoch: 0020 cost= 12745.773825000
# Epoch: 0021 cost= 12567.452355000
# Epoch: 0022 cost= 12399.364005000
# ...

# %%
lr = 0.001

# %%
run autoencoder-cifar.py adam 0.001
# Out:
# ...
# Train autoencoder on cifar10 dataset
# ...
# Optimizer: adam
# Learning rate: 0.001
# Momentum: 0.9
# Train set shape: (50000, 3072)
# Test set shape: (10000, 3072)
# Model restore from file: init_cifar.ckpt
# Epoch: 0001 cost= 38255.083350000
# Epoch: 0002 cost= 25443.040390000
# Epoch: 0003 cost= 21209.623570000
# Epoch: 0004 cost= 18448.716255000
# Epoch: 0005 cost= 17450.111190000
# Epoch: 0006 cost= 16790.564250000
# Epoch: 0007 cost= 15841.536995000
# Epoch: 0008 cost= 14977.233320000
# Epoch: 0009 cost= 14102.721740000
# Epoch: 0010 cost= 13146.557540000
# Epoch: 0011 cost= 12728.773140000
# Epoch: 0012 cost= 12518.523265000
# Epoch: 0013 cost= 12371.060265000
# Epoch: 0014 cost= 11993.403790000
# Epoch: 0015 cost= 11703.951585000
# Epoch: 0016 cost= 11421.660205000
# Epoch: 0017 cost= 11217.645690000
# Epoch: 0018 cost= 11059.392385000
# Epoch: 0019 cost= 10678.418685000
# Epoch: 0020 cost= 10353.221275000
# Epoch: 0021 cost= 10141.140430000
# Epoch: 0022 cost= 10003.014100000
# ...

# %%
lr = 0.001
epoch = 500

# %%
run autoencoder-cifar.py adam 0.001
# Out:
# ...
# Train autoencoder on cifar10 dataset
# ...
# Optimizer: adam
# Learning rate: 0.001
# Momentum: 0.9
# Train set shape: (50000, 3072)
# Test set shape: (10000, 3072)
# Model restore from file: init_cifar.ckpt
# Epoch: 0001 cost= 38255.083750000
# Epoch: 0002 cost= 25443.039320000
# Epoch: 0003 cost= 21209.623110000
# Epoch: 0004 cost= 18448.716580000
# Epoch: 0005 cost= 17450.111325000
# Epoch: 0006 cost= 16790.564480000
# Epoch: 0007 cost= 15841.536850000
# Epoch: 0008 cost= 14977.233410000
# Epoch: 0009 cost= 14102.721805000
# Epoch: 0010 cost= 13146.557630000
# Epoch: 0011 cost= 12728.773120000
# Epoch: 0012 cost= 12518.523025000
# Epoch: 0013 cost= 12371.060660000
# Epoch: 0014 cost= 11993.403925000
# Epoch: 0015 cost= 11703.951710000
# Epoch: 0016 cost= 11421.660105000
# Epoch: 0017 cost= 11217.645900000
# Epoch: 0018 cost= 11059.392320000
# Epoch: 0019 cost= 10678.419065000
# Epoch: 0020 cost= 10353.221340000
# Epoch: 0021 cost= 10141.140595000
# Epoch: 0022 cost= 10003.014335000
# ...

# %%
from IPython.display import Image
Image(filename='image/cifar10-adam.png')
