# %%
run Runner-mnist.py
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 cost= 28884.872697727
# Epoch: 0002 cost= 22533.320011364
# Epoch: 0003 cost= 21785.218561364
# Epoch: 0004 cost= 19432.114388636
# Epoch: 0005 cost= 21134.926350000
# Epoch: 0006 cost= 18574.637302273
# Epoch: 0007 cost= 18692.450093182
# Epoch: 0008 cost= 17341.933495455
# Epoch: 0009 cost= 16894.916039773
# Epoch: 0010 cost= 15382.474729545
# Epoch: 0011 cost= 15266.689368182
# Epoch: 0012 cost= 16864.641069318
# Epoch: 0013 cost= 16096.712743182
# Epoch: 0014 cost= 15522.161761364
# Epoch: 0015 cost= 14698.431780682
# Epoch: 0016 cost= 15038.710722727
# Epoch: 0017 cost= 14870.703585227
# Epoch: 0018 cost= 13881.880756818
# Epoch: 0019 cost= 15060.942205682
# Epoch: 0020 cost= 15218.504622727
# Epoch: 0021 cost= 14072.786490909
# Epoch: 0022 cost= 13571.181003409
# ...

# %%
from IPython.display import Image
Image(filename='mnist-adagrad.png')
