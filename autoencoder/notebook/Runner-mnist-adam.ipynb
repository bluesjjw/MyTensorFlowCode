# %%
run Runner-mnist.py
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 cost= 17726.355973864
# Epoch: 0002 cost= 10698.316426705
# Epoch: 0003 cost= 9756.095354545
# Epoch: 0004 cost= 7805.783663636
# Epoch: 0005 cost= 8455.892109659
# Epoch: 0006 cost= 7941.970926705
# Epoch: 0007 cost= 7245.093467614
# Epoch: 0008 cost= 7401.561440341
# Epoch: 0009 cost= 7173.279573295
# Epoch: 0010 cost= 6793.480369318
# Epoch: 0011 cost= 6101.541948295
# Epoch: 0012 cost= 6553.478636364
# Epoch: 0013 cost= 6627.765701136
# Epoch: 0014 cost= 6185.947957386
# Epoch: 0015 cost= 6415.088227273
# Epoch: 0016 cost= 6578.322174432
# Epoch: 0017 cost= 6607.083170455
# Epoch: 0018 cost= 5786.013148295
# Epoch: 0019 cost= 6460.918534659
# Epoch: 0020 cost= 6231.935788636
# Epoch: 0021 cost= 5798.353203977
# Epoch: 0022 cost= 5900.474180682
# ...

# %%
from IPython.display import Image
Image(filename='mnist-adam.png')
