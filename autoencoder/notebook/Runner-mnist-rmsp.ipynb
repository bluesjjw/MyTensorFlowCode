# %%
momentum = 0.1
run Runner-mnist.py
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 cost= 20135.872805682
# Epoch: 0002 cost= 12890.356360227
# Epoch: 0003 cost= 12914.665743182
# Epoch: 0004 cost= 11512.486907386
# Epoch: 0005 cost= 10997.075098864
# Epoch: 0006 cost= 10549.701018750
# Epoch: 0007 cost= 10719.966226705
# Epoch: 0008 cost= 10398.576256818
# Epoch: 0009 cost= 10064.363478977
# Epoch: 0010 cost= 10661.256795455
# Epoch: 0011 cost= 9371.796119886
# Epoch: 0012 cost= 9945.366482386
# Epoch: 0013 cost= 9858.307784659
# Epoch: 0014 cost= 9859.433156818
# Epoch: 0015 cost= 9400.513832386
# Epoch: 0016 cost= 11597.918406818
# Epoch: 0017 cost= 9133.317870455
# Epoch: 0018 cost= 9969.805973295
# Epoch: 0019 cost= 9709.747378977
# Epoch: 0020 cost= 8606.226639205
# Epoch: 0021 cost= 8836.626250000
# Epoch: 0022 cost= 9741.552686932
# ...

# %%
from IPython.display import Image
Image(filename='mnist-rmsp.png')
