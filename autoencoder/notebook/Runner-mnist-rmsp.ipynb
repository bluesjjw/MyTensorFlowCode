# %%
cd ..
# Out:
# /home/jiawei/code/github/MyTensorFlowCode/autoencoder

# %%
lr = 0.001
momentum = 0.9
# Out:
# /home/jiawei/code/github/MyTensorFlowCode/autoencoder

# %%
run autoencoder-all.py rmsp 0.001 0.9
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# 第0个参数是：autoencoder-all.py
# 第1个参数是：rmsp
# 第2个参数是：0.001
# 第3个参数是：0.9
# Model restore from file: None
# Epoch: 0001 cost= 11927.866472727
# Epoch: 0002 cost= 4756.775864773
# Epoch: 0003 cost= 2823.238854545
# Epoch: 0004 cost= 2130.345802841
# Epoch: 0005 cost= 1797.030427273
# Epoch: 0006 cost= 1591.140501136
# Epoch: 0007 cost= 1441.303008523
# Epoch: 0008 cost= 1327.726069318
# Epoch: 0009 cost= 1240.383930682
# Epoch: 0010 cost= 1167.618881250
# Epoch: 0011 cost= 1109.418679545
# Epoch: 0012 cost= 1060.232936364
# Epoch: 0013 cost= 1015.532207102
# Epoch: 0014 cost= 976.536953693
# Epoch: 0015 cost= 945.340548011
# Epoch: 0016 cost= 914.346822159
# Epoch: 0017 cost= 888.875653693
# Epoch: 0018 cost= 864.621580966
# Epoch: 0019 cost= 840.830733807
# Epoch: 0020 cost= 818.076850284
# ...

# %%
lr = 0.002
momentum = 0.9

# %%
run autoencoder-all.py rmsp 0.002 0.9
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# 第0个参数是：autoencoder-all.py
# 第1个参数是：rmsp
# 第2个参数是：0.002
# 第3个参数是：0.9
# Model restore from file: None
# Epoch: 0001 cost= 11163.463520455
# Epoch: 0002 cost= 3986.057582955
# Epoch: 0003 cost= 2418.033230682
# Epoch: 0004 cost= 1944.643655682
# Epoch: 0005 cost= 1696.789000568
# Epoch: 0006 cost= 1535.621230114
# Epoch: 0007 cost= 1420.674436364
# Epoch: 0008 cost= 1327.103389205
# Epoch: 0009 cost= 1260.249251705
# Epoch: 0010 cost= 1199.967936932
# Epoch: 0011 cost= 1155.798555682
# Epoch: 0012 cost= 1112.520185511
# Epoch: 0013 cost= 1083.483479830
# Epoch: 0014 cost= 1047.421949432
# Epoch: 0015 cost= 1023.938546591
# Epoch: 0016 cost= 1001.061123011
# Epoch: 0017 cost= 978.884813636
# Epoch: 0018 cost= 954.008182102
# Epoch: 0019 cost= 941.145981250
# Epoch: 0020 cost= 921.189875568
# ...

# %%
lr = 0.0008
momentum = 0.9

# %%
run autoencoder-all.py rmsp 0.0008 0.9
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# 第0个参数是：autoencoder-all.py
# 第1个参数是：rmsp
# 第2个参数是：0.0008
# 第3个参数是：0.9
# Model restore from file: None
# Epoch: 0001 cost= 12167.002652273
# Epoch: 0002 cost= 5058.627652273
# Epoch: 0003 cost= 3033.797084091
# Epoch: 0004 cost= 2280.956728977
# Epoch: 0005 cost= 1905.179866477
# Epoch: 0006 cost= 1679.876862500
# Epoch: 0007 cost= 1521.165465341
# Epoch: 0008 cost= 1397.554790909
# Epoch: 0009 cost= 1293.694252273
# Epoch: 0010 cost= 1211.385035227
# Epoch: 0011 cost= 1142.192938636
# Epoch: 0012 cost= 1087.152955966
# Epoch: 0013 cost= 1040.237372727
# Epoch: 0014 cost= 998.652982386
# Epoch: 0015 cost= 960.710204545
# Epoch: 0016 cost= 929.831645170
# Epoch: 0017 cost= 903.454870455
# Epoch: 0018 cost= 877.428913920
# Epoch: 0019 cost= 853.585247443
# Epoch: 0020 cost= 834.062394602
# ...

# %%
lr = 0.0007
momentum = 0.9

# %%
run autoencoder-all.py rmsp 0.0007 0.9
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# 第0个参数是：autoencoder-all.py
# 第1个参数是：rmsp
# 第2个参数是：0.0007
# 第3个参数是：0.9
# Model restore from file: None
# Epoch: 0001 cost= 12389.644772727
# Epoch: 0002 cost= 5259.405372727
# Epoch: 0003 cost= 3202.074311364
# Epoch: 0004 cost= 2421.508245455
# Epoch: 0005 cost= 1994.524665909
# Epoch: 0006 cost= 1755.334675568
# Epoch: 0007 cost= 1590.687120455
# Epoch: 0008 cost= 1460.694235227
# Epoch: 0009 cost= 1355.266423864
# Epoch: 0010 cost= 1268.939550000
# Epoch: 0011 cost= 1196.047250568
# Epoch: 0012 cost= 1134.318464205
# Epoch: 0013 cost= 1080.720548011
# Epoch: 0014 cost= 1033.246978693
# Epoch: 0015 cost= 992.414462500
# Epoch: 0016 cost= 959.900722727
# Epoch: 0017 cost= 928.210653693
# Epoch: 0018 cost= 901.064713352
# Epoch: 0019 cost= 875.909855114
# Epoch: 0020 cost= 851.438325568
# ...

# %%
lr = 0.0006
momentum = 0.9

# %%
run autoencoder-all.py rmsp 0.0006 0.9
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# 第0个参数是：autoencoder-all.py
# 第1个参数是：rmsp
# 第2个参数是：0.0006
# 第3个参数是：0.9
# Model restore from file: None
# Epoch: 0001 cost= 12459.440438636
# Epoch: 0002 cost= 5432.194562500
# Epoch: 0003 cost= 3370.634304545
# Epoch: 0004 cost= 2543.012425000
# Epoch: 0005 cost= 2077.366413068
# Epoch: 0006 cost= 1811.389644318
# Epoch: 0007 cost= 1626.215362500
# Epoch: 0008 cost= 1487.897843182
# Epoch: 0009 cost= 1377.011777841
# Epoch: 0010 cost= 1289.641143750
# Epoch: 0011 cost= 1212.461149432
# Epoch: 0012 cost= 1150.306296591
# Epoch: 0013 cost= 1097.023955114
# Epoch: 0014 cost= 1046.544614773
# Epoch: 0015 cost= 1007.379810511
# Epoch: 0016 cost= 972.833421023
# Epoch: 0017 cost= 941.858093750
# Epoch: 0018 cost= 911.710921307
# Epoch: 0019 cost= 886.201908523
# Epoch: 0020 cost= 861.689178409
# ...

# %%
from IPython.display import Image
Image(filename='image/mnist-rmsp.png')
