# %%
run Runner-mnist.py
# Out:
# Extracting ../mnist/train-images-idx3-ubyte.gz
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 cost= 35054.801786364
# Epoch: 0002 cost= 28495.784363636
# Epoch: 0003 cost= 26046.998381818
# Epoch: 0004 cost= 24497.850450000
# Epoch: 0005 cost= 22959.489997727
# Epoch: 0006 cost= 23134.494834091
# Epoch: 0007 cost= 21965.504222727
# Epoch: 0008 cost= 20487.762959091
# Epoch: 0009 cost= 20453.236286364
# Epoch: 0010 cost= 20784.596688636
# Epoch: 0011 cost= 19067.873885227
# Epoch: 0012 cost= 19111.585903409
# Epoch: 0013 cost= 19009.039469318
# Epoch: 0014 cost= 18132.731664773
# Epoch: 0015 cost= 17683.510475000
# Epoch: 0016 cost= 17464.723219318
# Epoch: 0017 cost= 18251.409477273
# Epoch: 0018 cost= 17827.608362500
# Epoch: 0019 cost= 17438.669098864
# Epoch: 0020 cost= 17424.794536364
# Epoch: 0021 cost= 17340.733526136
# Epoch: 0022 cost= 17197.902138636
# ...

# %%
from IPython.display import Image
Image(filename='mnist-ftrl.png')
